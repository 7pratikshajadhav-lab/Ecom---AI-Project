# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommers;

# %%
# %sql
USE CATALOG ecommers;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommers.broze;
CREATE SCHEMA IF NOT EXISTS ecommers.silver;
CREATE SCHEMA  IF NOT EXISTS ecommers.gold;

# %%
# %sql
SHOW DATABASES FROM ecommers;

# %%
# if you want to drope the cataloge:-
# %sql
# DROP CATALOG IF EXSISTS ecommers CASCADE;

# %%
# upload the csv files
